# %% [markdown]
# ## Helmholtz equation
#
# Let $n \in \{1,2,3\}$ be the number of dimensions we are working with.
#
# Let
#
# Find $u$
# $$
# \Delta u + k^2 u = -f
# $$

# %% [markdown]
# ## Homogeneous Helmholtz equation
#
# $$
# \Delta u + k^2 u = 0
# $$
# i.e
# $$
# \Delta u(x) = - k^2 u(x)
# $$
