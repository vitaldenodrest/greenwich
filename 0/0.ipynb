# %% [markdown]
# $$
# − \frac{d^2 u}{dx^2} − k^2 u = 0
# $$
#
# $$
# x \in [0, 1]
# $$
#
# $$
# \frac{du}{dx}(0) = ik u(0)
# $$
#
# $$
# \frac{du}{dx}(1) = ik u(1)
# $$

# %% [markdown]
# $$
# u(x) = A e^{ikx}
# $$

# %% [markdown]
# $$
# − \frac{d^2 u}{dx^2} \overline{v} − k^2 u \overline{v} = 0
# $$
#
# $$
# - \int_{0}^{1} \frac{d^2 u}{dx^2}(x) \overline{v(x)} \,dx - k^2 \int_{0}^{1} u(x) \overline{v(x)} \,dx = 0
# $$
#
# $$
# \int_{0}^{1} \frac{du}{dx}(x) \overline{\frac{dv}{dx}(x)} \,dx - k^2 \int_{0}^{1} u(x) \overline{v(x)} \,dx + ik \Bigl( u(0)\overline{v(0)} - u(1)\overline{v(1)} \Bigr) = 0
# $$
